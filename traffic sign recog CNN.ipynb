# %% [markdown]
# # Play around with the image data (Ignore this!)
#
# #Prepare train data, including train images with labels:

# %%
from crop_traffic_signs import *
train_images, train_labels = crop_train_traffic_signs(
    train_path= 'E:\COGNITIVE_SCIENCE\ARTIFICIAL_INTELLIGENCE\ROBOTICS\german_traffic_recog_benchmark\Final_Training\Images',
train_dest= 'E:/COGNITIVE_SCIENCE/ARTIFICIAL_INTELLIGENCE/ROBOTICS/Auto_DRIVING/train_traffic_signs_cropped')

# %%
print "So luong ảnh huan luyen va nhãn : ", len(train_images), len(train_labels)
thu = 1000
print "kich thuoc cua ảnh dau tien va nhãn tuong ung: " ,train_images[thu].shape, train_labels[thu]
import matplotlib.pyplot as plt
# %matplotlib inline
plt.imshow(train_images[thu])
#print train_labels[00010000]
# Out:
# So luong ảnh huan luyen va nhãn :  39209 39209
# kich thuoc cua ảnh dau tien va nhãn tuong ung:  (52L, 52L, 3L) 1

# %% [markdown]
# Ảnh là một vector 3 chiều. (chiều dài, rộng và sâu) của ảnh, trong đó chiều sâu là 3 kênh màu của ảnh RGB
# Có nhiều ảnh mờ quá thể, đến mình còn k phân biệt được, nói j đến máy

# %% [markdown]
# # Đã có ảnh, chỉ cần chạy đoạn này là xong:

# %%
train_path = 'E:/COGNITIVE_SCIENCE/ARTIFICIAL_INTELLIGENCE/ROBOTICS/Auto_DRIVING/train_traffic_signs_cropped'
import graphlab as gl
path = train_path+'/'
train_sf = gl.image_analysis.load_images(path, format='PNG')
gl.canvas.set_target('ipynb')
train_sf.head()#['image']#.head()
# Out:
# A newer version of GraphLab Create (v1.9) is available! Your current version is v1.8.3.
#
# You can use pip to upgrade the graphlab-create package. For more information see https://dato.com/products/create/upgrade.
# [INFO] GraphLab Create v1.8.3 started. Logging: C:\Users\admin\AppData\Local\Temp\graphlab_server_1461958370.log.0
# Columns:
# 	path	str
# 	image	Image
#
# Rows: 10
#
# Data:
# +-------------------------------+----------------------+
# |              path             |        image         |
# +-------------------------------+----------------------+
# | E:/COGNITIVE_SCIENCE/ARTIF... | Height: 15 Width: 15 |
# | E:/COGNITIVE_SCIENCE/ARTIF... | Height: 18 Width: 18 |
# | E:/COGNITIVE_SCIENCE/ARTIF... | Height: 23 Width: 25 |
# | E:/COGNITIVE_SCIENCE/ARTIF... | Height: 37 Width: 32 |
# | E:/COGNITIVE_SCIENCE/ARTIF... | Height: 84 Width: 84 |
# | E:/COGNITIVE_SCIENCE/ARTIF... | Height: 25 Width: 25 |
# | E:/COGNITIVE_SCIENCE/ARTIF... | Height: 23 Width: 20 |
# ...

# %%
test_sf#.shape()
# Out:
# Columns:
# 	path	str
# 	image	Image
#
# Rows: 39209
#
# Data:
# +-------------------------------+----------------------+
# |              path             |        image         |
# +-------------------------------+----------------------+
# | E:/COGNITIVE_SCIENCE/ARTIF... | Height: 15 Width: 15 |
# | E:/COGNITIVE_SCIENCE/ARTIF... | Height: 18 Width: 18 |
# | E:/COGNITIVE_SCIENCE/ARTIF... | Height: 23 Width: 25 |
# | E:/COGNITIVE_SCIENCE/ARTIF... | Height: 37 Width: 32 |
# | E:/COGNITIVE_SCIENCE/ARTIF... | Height: 84 Width: 84 |
# | E:/COGNITIVE_SCIENCE/ARTIF... | Height: 25 Width: 25 |
# | E:/COGNITIVE_SCIENCE/ARTIF... | Height: 23 Width: 20 |
# | E:/COGNITIVE_SCIENCE/ARTIF... | Height: 36 Width: 37 |
# | E:/COGNITIVE_SCIENCE/ARTIF... | Height: 32 Width: 32 |
# | E:/COGNITIVE_SCIENCE/ARTIF... | Height: 25 Width: 29 |
# +-------------------------------+----------------------+
# [39209 rows x 2 columns]
# Note: Only the head of the SFrame is printed.
# ...

# %%
test_sf['label'] = test_sf['path'].apply(lambda x: int(x.split('/')[-1][:5]))
test_sf
# Out:
# Columns:
# 	path	str
# 	image	Image
# 	label	int
#
# Rows: 39209
#
# Data:
# +-------------------------------+----------------------+-------+
# |              path             |        image         | label |
# +-------------------------------+----------------------+-------+
# | E:/COGNITIVE_SCIENCE/ARTIF... | Height: 15 Width: 15 |   18  |
# | E:/COGNITIVE_SCIENCE/ARTIF... | Height: 18 Width: 18 |   8   |
# | E:/COGNITIVE_SCIENCE/ARTIF... | Height: 23 Width: 25 |   24  |
# | E:/COGNITIVE_SCIENCE/ARTIF... | Height: 37 Width: 32 |   15  |
# | E:/COGNITIVE_SCIENCE/ARTIF... | Height: 84 Width: 84 |   9   |
# | E:/COGNITIVE_SCIENCE/ARTIF... | Height: 25 Width: 25 |   5   |
# | E:/COGNITIVE_SCIENCE/ARTIF... | Height: 23 Width: 20 |   38  |
# | E:/COGNITIVE_SCIENCE/ARTIF... | Height: 36 Width: 37 |   6   |
# | E:/COGNITIVE_SCIENCE/ARTIF... | Height: 32 Width: 32 |   10  |
# | E:/COGNITIVE_SCIENCE/ARTIF... | Height: 25 Width: 29 |   26  |
# ...

# %%
int(test_sf[0]['path'].split('/')[-1][:5])
# Out:
# 18

# %%
print "So luong ảnh huan luyen va nhãn : ", len(train_images), len(train_labels)
thu = 0
print "kich thuoc cua ảnh dau tien va nhãn tuong ung: " ,train_images[thu].shape, train_labels[thu]
import matplotlib.pyplot as plt
# %matplotlib inline
plt.imshow(train_images[thu])
#print train_labels[00010000]
# Out:
# So luong ảnh huan luyen va nhãn :  39209 39209
# kich thuoc cua ảnh dau tien va nhãn tuong ung:  (19L, 19L, 3L) 0

# %%
test_sf.save('train_sframe/')
# Out:
# C:\Users\admin\train_sframe

# %%
train_sf = gl.load_sframe('train_sframe')

# %%
train_sf
# Out:
# Columns:
# 	path	str
# 	image	Image
# 	label	int
#
# Rows: 39209
#
# Data:
# +-------------------------------+----------------------+-------+
# |              path             |        image         | label |
# +-------------------------------+----------------------+-------+
# | E:/COGNITIVE_SCIENCE/ARTIF... | Height: 15 Width: 15 |   18  |
# | E:/COGNITIVE_SCIENCE/ARTIF... | Height: 18 Width: 18 |   8   |
# | E:/COGNITIVE_SCIENCE/ARTIF... | Height: 23 Width: 25 |   24  |
# | E:/COGNITIVE_SCIENCE/ARTIF... | Height: 37 Width: 32 |   15  |
# | E:/COGNITIVE_SCIENCE/ARTIF... | Height: 84 Width: 84 |   9   |
# | E:/COGNITIVE_SCIENCE/ARTIF... | Height: 25 Width: 25 |   5   |
# | E:/COGNITIVE_SCIENCE/ARTIF... | Height: 23 Width: 20 |   38  |
# | E:/COGNITIVE_SCIENCE/ARTIF... | Height: 36 Width: 37 |   6   |
# | E:/COGNITIVE_SCIENCE/ARTIF... | Height: 32 Width: 32 |   10  |
# | E:/COGNITIVE_SCIENCE/ARTIF... | Height: 25 Width: 29 |   26  |
# ...

# %% [markdown]
# ## Lẫy mẫu từ tập dữ liệu học vừa đọc được:

# %%
import random 
# sampling 1000 training images
train_samples = random.sample(xrange(len(train_images)), 1000)
#print train_samples
sample_train_images = np.array(train_images)[np.array(train_samples)]
sample_train_labels = np.array(train_labels)[np.array(train_samples)]
print "số lượng ảnh mẫu: ", len(sample_train_images)
print "ảnh học đầu tiên: ", sample_train_images[0].shape
# Out:
# số lượng ảnh mẫu:  1000
# ảnh học đầu tiên:  (36L, 39L, 3L)

# %% [markdown]
# # Prepare test data (images with labels):

# %%
from crop_traffic_signs import *
test_path = 'E:\COGNITIVE_SCIENCE\ARTIFICIAL_INTELLIGENCE\ROBOTICS\german_traffic_recog_benchmark\GTSRB_Final_Test_Images\Final_Test\Images'
test_dest = 'E:/COGNITIVE_SCIENCE/ARTIFICIAL_INTELLIGENCE/ROBOTICS/Auto_DRIVING/test_traffic_signs_cropped'
test_images, test_labels = crop_test_traffic_signs(test_path,test_dest)

# %%
print "số lượng ảnh kiểm tra: ", len(test_images)
# Out:
# số lượng ảnh kiểm tra:  12630

# %% [markdown]
# # Đang đọc ảnh png vào sframe!

# %%
test_path = 'E:/COGNITIVE_SCIENCE/ARTIFICIAL_INTELLIGENCE/ROBOTICS/Auto_DRIVING/test_traffic_signs_cropped'
import graphlab as gl
path = test_path+'/'
test_sf = gl.image_analysis.load_images(path, format='PNG')
gl.canvas.set_target('ipynb')
test_sf#.head()#['image']#.head()
# Out:
# A newer version of GraphLab Create (v1.9) is available! Your current version is v1.8.3.
#
# You can use pip to upgrade the graphlab-create package. For more information see https://dato.com/products/create/upgrade.
# [INFO] GraphLab Create v1.8.3 started. Logging: C:\Users\admin\AppData\Local\Temp\graphlab_server_1461962690.log.0
# Columns:
# 	path	str
# 	image	Image
#
# Rows: 12630
#
# Data:
# +-------------------------------+----------------------+
# |              path             |        image         |
# +-------------------------------+----------------------+
# | E:/COGNITIVE_SCIENCE/ARTIF... | Height: 16 Width: 16 |
# | E:/COGNITIVE_SCIENCE/ARTIF... | Height: 16 Width: 16 |
# | E:/COGNITIVE_SCIENCE/ARTIF... | Height: 24 Width: 21 |
# | E:/COGNITIVE_SCIENCE/ARTIF... | Height: 24 Width: 18 |
# | E:/COGNITIVE_SCIENCE/ARTIF... | Height: 18 Width: 18 |
# | E:/COGNITIVE_SCIENCE/ARTIF... | Height: 45 Width: 45 |
# | E:/COGNITIVE_SCIENCE/ARTIF... | Height: 25 Width: 24 |
# ...

# %%
int(test_sf[0]['path'].split('/')[-1].split('_')[0])
# Out:
# 26

# %%
test_sf['label'] = test_sf['path'].apply(lambda x: int(x.split('/')[-1].split('_')[0]))

# %%
test_sf.save('test_sframe')
# Out:
# C:\Users\admin\test_sframe

# %%
test = gl.load_sframe('test_sframe')

# %%
test
# Out:
# Columns:
# 	path	str
# 	image	Image
# 	label	int
#
# Rows: 12630
#
# Data:
# +-------------------------------+----------------------+-------+
# |              path             |        image         | label |
# +-------------------------------+----------------------+-------+
# | E:/COGNITIVE_SCIENCE/ARTIF... | Height: 16 Width: 16 |   26  |
# | E:/COGNITIVE_SCIENCE/ARTIF... | Height: 16 Width: 16 |   8   |
# | E:/COGNITIVE_SCIENCE/ARTIF... | Height: 24 Width: 21 |   17  |
# | E:/COGNITIVE_SCIENCE/ARTIF... | Height: 24 Width: 18 |   38  |
# | E:/COGNITIVE_SCIENCE/ARTIF... | Height: 18 Width: 18 |   35  |
# | E:/COGNITIVE_SCIENCE/ARTIF... | Height: 45 Width: 45 |   42  |
# | E:/COGNITIVE_SCIENCE/ARTIF... | Height: 25 Width: 24 |   17  |
# | E:/COGNITIVE_SCIENCE/ARTIF... | Height: 19 Width: 18 |   4   |
# | E:/COGNITIVE_SCIENCE/ARTIF... | Height: 24 Width: 24 |   1   |
# | E:/COGNITIVE_SCIENCE/ARTIF... | Height: 21 Width: 22 |   2   |
# ...

# %%
train = gl.load_sframe('train_sframe')

# %%
train
# Out:
# Columns:
# 	path	str
# 	image	Image
# 	label	int
#
# Rows: 39209
#
# Data:
# +-------------------------------+----------------------+-------+
# |              path             |        image         | label |
# +-------------------------------+----------------------+-------+
# | E:/COGNITIVE_SCIENCE/ARTIF... | Height: 15 Width: 15 |   18  |
# | E:/COGNITIVE_SCIENCE/ARTIF... | Height: 18 Width: 18 |   8   |
# | E:/COGNITIVE_SCIENCE/ARTIF... | Height: 23 Width: 25 |   24  |
# | E:/COGNITIVE_SCIENCE/ARTIF... | Height: 37 Width: 32 |   15  |
# | E:/COGNITIVE_SCIENCE/ARTIF... | Height: 84 Width: 84 |   9   |
# | E:/COGNITIVE_SCIENCE/ARTIF... | Height: 25 Width: 25 |   5   |
# | E:/COGNITIVE_SCIENCE/ARTIF... | Height: 23 Width: 20 |   38  |
# | E:/COGNITIVE_SCIENCE/ARTIF... | Height: 36 Width: 37 |   6   |
# | E:/COGNITIVE_SCIENCE/ARTIF... | Height: 32 Width: 32 |   10  |
# | E:/COGNITIVE_SCIENCE/ARTIF... | Height: 25 Width: 29 |   26  |
# ...

# %%
train, valid = train.random_split(.8)

# %%
train['image'] = gl.image_analysis.resize(train['image'],24,24,1)
valid['image'] = gl.image_analysis.resize(valid['image'],24,24,1)

# %%
train
# Out:
# Columns:
# 	path	str
# 	image	Image
# 	label	int
#
# Rows: 31304
#
# Data:
# +-------------------------------+----------------------+-------+
# |              path             |        image         | label |
# +-------------------------------+----------------------+-------+
# | E:/COGNITIVE_SCIENCE/ARTIF... | Height: 24 Width: 24 |   8   |
# | E:/COGNITIVE_SCIENCE/ARTIF... | Height: 24 Width: 24 |   24  |
# | E:/COGNITIVE_SCIENCE/ARTIF... | Height: 24 Width: 24 |   15  |
# | E:/COGNITIVE_SCIENCE/ARTIF... | Height: 24 Width: 24 |   38  |
# | E:/COGNITIVE_SCIENCE/ARTIF... | Height: 24 Width: 24 |   6   |
# | E:/COGNITIVE_SCIENCE/ARTIF... | Height: 24 Width: 24 |   26  |
# | E:/COGNITIVE_SCIENCE/ARTIF... | Height: 24 Width: 24 |   18  |
# | E:/COGNITIVE_SCIENCE/ARTIF... | Height: 24 Width: 24 |   25  |
# | E:/COGNITIVE_SCIENCE/ARTIF... | Height: 24 Width: 24 |   26  |
# | E:/COGNITIVE_SCIENCE/ARTIF... | Height: 24 Width: 24 |   28  |
# ...

# %%
valid
# Out:
# Columns:
# 	path	str
# 	image	Image
# 	label	int
#
# Rows: 7905
#
# Data:
# +-------------------------------+----------------------+-------+
# |              path             |        image         | label |
# +-------------------------------+----------------------+-------+
# | E:/COGNITIVE_SCIENCE/ARTIF... | Height: 24 Width: 24 |   18  |
# | E:/COGNITIVE_SCIENCE/ARTIF... | Height: 24 Width: 24 |   9   |
# | E:/COGNITIVE_SCIENCE/ARTIF... | Height: 24 Width: 24 |   5   |
# | E:/COGNITIVE_SCIENCE/ARTIF... | Height: 24 Width: 24 |   10  |
# | E:/COGNITIVE_SCIENCE/ARTIF... | Height: 24 Width: 24 |   4   |
# | E:/COGNITIVE_SCIENCE/ARTIF... | Height: 24 Width: 24 |   41  |
# | E:/COGNITIVE_SCIENCE/ARTIF... | Height: 24 Width: 24 |   24  |
# | E:/COGNITIVE_SCIENCE/ARTIF... | Height: 24 Width: 24 |   33  |
# | E:/COGNITIVE_SCIENCE/ARTIF... | Height: 24 Width: 24 |   18  |
# | E:/COGNITIVE_SCIENCE/ARTIF... | Height: 24 Width: 24 |   12  |
# ...

# %%
test['image'] = gl.image_analysis.resize(test['image'],24,24,1)

# %%
>>> net = gl.deeplearning.create(train, target='label')

# %%
>>> net.layers
# Out:
# layer[0]: ConvolutionLayer
#   init_random = gaussian
#   padding = 0
#   stride = 2
#   num_channels = 10
#   num_groups = 1
#   kernel_size = 3
# layer[1]: MaxPoolingLayer
#   padding = 0
#   stride = 2
#   kernel_size = 3
# layer[2]: FlattenLayer
# layer[3]: FullConnectionLayer
#   init_sigma = 0.01
#   init_random = gaussian
#   init_bias = 0
#   num_hidden_units = 100
# layer[4]: RectifiedLinearLayer
# layer[5]: DropoutLayer
#   threshold = 0.5
# layer[6]: FullConnectionLayer
#   init_sigma = 0.01
#   init_random = gaussian
#   init_bias = 0
#   num_hidden_units = 43
# layer[7]: SoftmaxLayer

# %%
net
# Out:
# ### network layers ###
# layer[0]: ConvolutionLayer
#   init_random = gaussian
#   padding = 0
#   stride = 2
#   num_channels = 10
#   num_groups = 1
#   kernel_size = 3
# layer[1]: MaxPoolingLayer
#   padding = 0
#   stride = 2
#   kernel_size = 3
# layer[2]: FlattenLayer
# layer[3]: FullConnectionLayer
#   init_sigma = 0.01
#   init_random = gaussian
#   init_bias = 0
#   num_hidden_units = 100
# layer[4]: RectifiedLinearLayer
#   num_hidden_units = 10
# layer[5]: DropoutLayer
#   threshold = 0.5
# layer[6]: FullConnectionLayer
#   init_sigma = 0.01
#   init_random = gaussian
#   init_bias = 0
#   num_hidden_units = 43
# layer[7]: SoftmaxLayer
# ### end network layers ###
#
# ### network parameters ###
# learning_rate = 0.001
# momentum = 0.9
# ### end network parameters ###

# %%
>>> net.params
# Out:
# {'learning_rate': 0.001, 'momentum': 0.9}

# %%
>>> net.layers[4].num_hidden_units = 10

# %%
>>> percpt_net = gl.deeplearning.MultiLayerPerceptrons(num_hidden_layers=3,
                                                num_hidden_units=[15,10,10])
percpt_net

# %%
percpt_net
# Out:
# ### network layers ###
# layer[0]: FullConnectionLayer
#   init_sigma = 0.01
#   init_random = gaussian
#   init_bias = 0
#   num_hidden_units = 15
# layer[1]: SigmoidLayer
# layer[2]: FullConnectionLayer
#   init_sigma = 0.01
#   init_random = gaussian
#   init_bias = 0
#   num_hidden_units = 10
# layer[3]: SigmoidLayer
# layer[4]: FullConnectionLayer
#   init_sigma = 0.01
#   init_random = gaussian
#   init_bias = 0
#   num_hidden_units = 10
# layer[5]: SoftmaxLayer
# ### end network layers ###
#
# ### network parameters ###
# learning_rate = 0.001
# momentum = 0.9
# ### end network parameters ###

# %%
m = gl.neuralnet_classifier.create(train, target='label',
...                                          network = percpt_net,
...                                          validation_set=valid,
...                                          metric=['accuracy', 'recall@2'],
...                                          max_iterations=3)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-80-0bfbea91d8fd> in <module>()
#       3                                          validation_set=valid,
#       4                                          metric=['accuracy', 'recall@2'],
# ----> 5                                          max_iterations=3)
#
# C:\Users\admin\AppData\Local\Dato\Dato Launcher\lib\site-packages\graphlab\toolkits\classifier\neuralnet_classifier.pyc in create(dataset, target, features, max_iterations, network, validation_set, verbose, class_weights, **kwargs)
#     951     # use user specified network
#     952         _network = _copy(network)
# --> 953         input_shape = _deeplearning._get_input_shape(dataset, target, features)
#     954         output_shape = _deeplearning._get_output_shape(dataset[target])
#     955         # verify the netwo
#
# ...

# %%
>>> eval_ = m.evaluate(test_data)
>>> eval_
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-45-b063b91b65d1> in <module>()
# ----> 1 eval_ = m.evaluate(test_data)
#       2 eval_
#
# NameError: name 'm' is not defined

# %%
import graphlab
raw_pixel_model = graphlab.logistic_classifier.create(train,target='label',
                                              features=['image_array'])
# Out:
# Logistic regression:
# --------------------------------------------------------
# Number of examples          : 29723
# Number of classes           : 43
# Number of feature columns   : 1
# Number of unpacked features : 576
# Number of coefficients    : 24234
# Starting L-BFGS
# --------------------------------------------------------
# +-----------+----------+-----------+--------------+-------------------+---------------------+
# | Iteration | Passes   | Step size | Elapsed Time | Training-accuracy | Validation-accuracy |
# +-----------+----------+-----------+--------------+-------------------+---------------------+
# | 1         | 6        | 0.000002  | 217.513951   | 0.055849          | 0.060089            |
# | 2         | 8        | 1.000000  | 289.601544   | 0.125997          | 0.122075            |
# | 3         | 9        | 1.000000  | 326.475006   | 0.201595          | 0.202404            |
# ...

# %%
raw_pixel_model.save("whole image")

# %%
raw_pixel_model.evaluate(test)
# Out:
# {'accuracy': 0.4119556611243072,
#  'auc': 0.768052026489976,
#  'confusion_matrix': Columns:
#  	target_label	int
#  	predicted_label	int
#  	count	int
#
#  Rows: 481
#
#  Data:
#  +--------------+-----------------+-------+
#  | target_label | predicted_label | count |
#  +--------------+-----------------+-------+
#  |      17      |        12       |   13  |
#  |      1       |        4        |   9   |
#  |      17      |        18       |   3   |
#  |      8       |        38       |   23  |
#  |      3       |        13       |   1   |
#  |      23      |        5        |   4   |
#  |      9       |        5        |   18  |
#  |      5       |        13       |   4   |
#  |      18      |        1        |   6   |
#  |      15      |        13       |   2   |
#  +--------------+-----------------+-------+
#  [481 rows x 3 columns]
#  Note: Only the head of the SFrame is printed.
#  You can use print_rows(num_rows=m, num_columns=n) to print more rows and columns.,
# ...

# %%
deep_learning_model = graphlab.load_model('http://s3.amazonaws.com/GraphLab-Datasets/deeplearning/imagenet_model_iter45')
train['deep_features'] = deep_learning_model.extract_features(train)
# Out:
# ...
# Images being resized.

# %%
test['deep_features'] = deep_learning_model.extract_features(test)
# Out:
# Images being resized.

# %%
train
# Out:
# Columns:
# 	path	str
# 	image	Image
# 	label	int
# 	image_array	array
# 	deep_features	array
#
# Rows: 31304
#
# Data:
# +-------------------------------+----------------------+-------+
# |              path             |        image         | label |
# +-------------------------------+----------------------+-------+
# | E:/COGNITIVE_SCIENCE/ARTIF... | Height: 24 Width: 24 |   8   |
# | E:/COGNITIVE_SCIENCE/ARTIF... | Height: 24 Width: 24 |   24  |
# | E:/COGNITIVE_SCIENCE/ARTIF... | Height: 24 Width: 24 |   15  |
# | E:/COGNITIVE_SCIENCE/ARTIF... | Height: 24 Width: 24 |   38  |
# | E:/COGNITIVE_SCIENCE/ARTIF... | Height: 24 Width: 24 |   6   |
# | E:/COGNITIVE_SCIENCE/ARTIF... | Height: 24 Width: 24 |   26  |
# | E:/COGNITIVE_SCIENCE/ARTIF... | Height: 24 Width: 24 |   18  |
# | E:/COGNITIVE_SCIENCE/ARTIF... | Height: 24 Width: 24 |   25  |
# | E:/COGNITIVE_SCIENCE/ARTIF... | Height: 24 Width: 24 |   26  |
# | E:/COGNITIVE_SCIENCE/ARTIF... | Height: 24 Width: 24 |   28  |
# ...

# %%
valid.save('valid wo deep')
# Out:
# C:\Users\admin\valid wo deep

# %%
test.head()
# Out:
# Columns:
# 	path	str
# 	image	Image
# 	label	int
# 	image_array	array
# 	deep_features	array
#
# Rows: 10
#
# Data:
# +-------------------------------+----------------------+-------+
# |              path             |        image         | label |
# +-------------------------------+----------------------+-------+
# | E:/COGNITIVE_SCIENCE/ARTIF... | Height: 24 Width: 24 |   26  |
# | E:/COGNITIVE_SCIENCE/ARTIF... | Height: 24 Width: 24 |   8   |
# | E:/COGNITIVE_SCIENCE/ARTIF... | Height: 24 Width: 24 |   17  |
# | E:/COGNITIVE_SCIENCE/ARTIF... | Height: 24 Width: 24 |   38  |
# | E:/COGNITIVE_SCIENCE/ARTIF... | Height: 24 Width: 24 |   35  |
# | E:/COGNITIVE_SCIENCE/ARTIF... | Height: 24 Width: 24 |   42  |
# | E:/COGNITIVE_SCIENCE/ARTIF... | Height: 24 Width: 24 |   17  |
# | E:/COGNITIVE_SCIENCE/ARTIF... | Height: 24 Width: 24 |   4   |
# | E:/COGNITIVE_SCIENCE/ARTIF... | Height: 24 Width: 24 |   1   |
# | E:/COGNITIVE_SCIENCE/ARTIF... | Height: 24 Width: 24 |   2   |
# ...

# %%
train.save('train with deep')
# Out:
# C:\Users\admin\train with deep

# %%
test.save('test with deep')
# Out:
# C:\Users\admin\test with deep

# %%
deep_features_model = graphlab.logistic_classifier.create(train,
                                                         features=['deep_features'],
                                                         target='label')
# Out:
# WARNING: Detected extremely low variance for feature(s) 'deep_features' because all entries are nearly the same.
# Proceeding with model training using all features. If the model does not provide results of adequate quality, exclude the above mentioned feature(s) from the input dataset.
# Logistic regression:
# --------------------------------------------------------
# Number of examples          : 29758
# Number of classes           : 43
# Number of feature columns   : 1
# Number of unpacked features : 4096
# Number of coefficients    : 172074
# Starting L-BFGS
# --------------------------------------------------------
# +-----------+----------+-----------+--------------+-------------------+---------------------+
# | Iteration | Passes   | Step size | Elapsed Time | Training-accuracy | Validation-accuracy |
# +-----------+----------+-----------+--------------+-------------------+---------------------+
# ...

# %%
deep_features_model.evaluate(test)
# Out:
# {'accuracy': 0.7615993665874901,
#  'auc': 0.9806036424003313,
#  'confusion_matrix': Columns:
#  	target_label	int
#  	predicted_label	int
#  	count	int
#
#  Rows: 444
#
#  Data:
#  +--------------+-----------------+-------+
#  | target_label | predicted_label | count |
#  +--------------+-----------------+-------+
#  |      6       |        37       |   3   |
#  |      12      |        18       |   2   |
#  |      18      |        3        |   2   |
#  |      20      |        24       |   3   |
#  |      24      |        26       |   5   |
#  |      38      |        9        |   2   |
#  |      22      |        27       |   4   |
#  |      38      |        26       |   1   |
#  |      35      |        36       |   1   |
#  |      4       |        6        |   3   |
#  +--------------+-----------------+-------+
#  [444 rows x 3 columns]
#  Note: Only the head of the SFrame is printed.
#  You can use print_rows(num_rows=m, num_columns=n) to print more rows and columns.,
# ...

# %%
deep_features_model.save('pretrained imagenet')

# %%
raw_pixel_model.save('whole image ')

# %%
train['image'].show()

# %%
test['image'].show()

# %% [markdown]
# Ở trên là Scalable Array của Dato (SArray). Họ đã làm cho nó rất dễ đọc và visualise. Nó k chỉ chứa kích thước, mà cả ảnh trong đó.

# %% [markdown]
# # Tạo một cột gồm ma trận ảnh (cho chắc!):

# %%
from array import array
train['image_array'] = train['image'].astype(array)

# %%
test['image_array'] = test['image'].astype(array)

# %%
train.remove_column('img_array')
train
# Out:
# Columns:
# 	path	str
# 	image	Image
# 	label	int
# 	image_array	array
#
# Rows: 31304
#
# Data:
# +-------------------------------+----------------------+-------+
# |              path             |        image         | label |
# +-------------------------------+----------------------+-------+
# | E:/COGNITIVE_SCIENCE/ARTIF... | Height: 24 Width: 24 |   8   |
# | E:/COGNITIVE_SCIENCE/ARTIF... | Height: 24 Width: 24 |   24  |
# | E:/COGNITIVE_SCIENCE/ARTIF... | Height: 24 Width: 24 |   15  |
# | E:/COGNITIVE_SCIENCE/ARTIF... | Height: 24 Width: 24 |   38  |
# | E:/COGNITIVE_SCIENCE/ARTIF... | Height: 24 Width: 24 |   6   |
# | E:/COGNITIVE_SCIENCE/ARTIF... | Height: 24 Width: 24 |   26  |
# | E:/COGNITIVE_SCIENCE/ARTIF... | Height: 24 Width: 24 |   18  |
# | E:/COGNITIVE_SCIENCE/ARTIF... | Height: 24 Width: 24 |   25  |
# | E:/COGNITIVE_SCIENCE/ARTIF... | Height: 24 Width: 24 |   26  |
# | E:/COGNITIVE_SCIENCE/ARTIF... | Height: 24 Width: 24 |   28  |
# ...

# %%
import matplotlib.pyplot as plot 
# %matplotlib inline
thu_anh = 0
print "kích thước của ảnh thử: ", test_images[thu_anh].shape, test_labels[thu_anh]
plot.imshow(test_images[thu_anh])
# Out:
# kích thước của ảnh thử:  (44L, 42L, 3L) 16

# %%
import graphlab as gl 
test_label = gl.SArray(data=test_labels)

# %%
#print python __version__
import platform as pf
print pf.python_version()
# Out:
# 2.7.10

# %%
test_label.head()
# Out:
# dtype: str
# Rows: 10
# ['16', '1', '38', '33', '11', '38', '18', '12', '25', '35']

# %%
import numpy as np
test_image = gl.SArray(data=np.asarray(test_images))

# %%
test_image.head()
# Out:
# dtype: str
# Rows: 10
# ['16', '1', '38', '33', '11', '38', '18', '12', '25', '35']

# %%
#plt.imshow(test_images[0])
#plt.show()
print "số lượng ảnh kiểm tra: ", len(test_images)
print "kích thước của ảnh đầu tiên: ", test_images[10].shape
# Out:
# số lượng ảnh kiểm tra:  12630
# kích thước của ảnh đầu tiên:  (37L, 38L, 3L)

# %%
import random 
# random sampling 100 test images:
test_samples = random.sample(xrange(len(test_images)), 100)
#print train_samples
sample_test_images = np.array(test_images)[np.array(test_samples)]
sample_test_labels = np.array(test_labels)[np.array(test_samples)]
print "số ảnh kiểm tra mẫu: ", len(sample_test_labels)
print "ảnh kiểm tra mẫu đầu tiên có kích thước: ", sample_test_images[0].shape
# Out:
# số ảnh kiểm tra mẫu:  100
# ảnh kiểm tra mẫu đầu tiên có kích thước:  (34L, 27L, 3L)

# %% [markdown]
# # Trích chọn đặc tính:

# %%
from features import *
#from features import *
#import numpy as np
sample_train_features = extract_features(sample_train_images, [lambda img: color_histogram_hsv(img, nbin=100)])#,hog_feature], verbose=True)
sample_test_features = extract_features(sample_test_images, [lambda img: color_histogram_hsv(img, nbin=100)])#,hog_feature], verbose=True)#, [hog_feature])

print "kích thước của thuộc tính học: ", sample_train_features[0].shape
print "kích thước của thuộc tính kiểm tra: ",sample_test_features[0].shape
# Out:
# kích thước của thuộc tính học:  100
# kích thước của thuộc tính kiểm tra:  (100L,)

# %% [markdown]
# 10 ở đây là số bins trong histogram màu

# %% [markdown]
# #Fit a model and evalute it:

# %%
from learn import*
learn(sample_train_features, sample_train_labels, sample_test_features, sample_test_labels, model = svm.SVC())
# Out:
# Score is: 0.070000:
# (0.070000000000000007,
#  SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0, degree=3, gamma=0.0,
#    kernel='rbf', max_iter=-1, probability=False, random_state=None,
#    shrinking=True, tol=0.001, verbose=False))

# %% [markdown]
# #score(trainDataReader, testDataReader, featureExtractor, classifier)

# %%
train_path = 'E:\COGNITIVE_SCIENCE\ARTIFICIAL_INTELLIGENCE\ROBOTICS\german_traffic_recog_benchmark\Final_Training\Images'
test_path = 'E:\COGNITIVE_SCIENCE\ARTIFICIAL_INTELLIGENCE\ROBOTICS\german_traffic_recog_benchmark\GTSRB_Final_Test_Images\Final_Test\Images'

from readTrafficSigns import *
from features import *
from learn import *
learn(read_train_traffic_signs(train_path, sample_ratio=.1), read_test_traffic_signs(test_path, sample_ratio=.1), 
      [lambda img: img.flatten()[:1000]], model=linear_model.LogisticRegression() )
# Out:
# sample size:  3920
# first lesson:  (128L, 137L, 3L)
# sample test size:  1263
# first test:  (55L, 50L, 3L)
# Done extracting features for 1000 / 3920 images
# Done extracting features for 2000 / 3920 images
# Done extracting features for 3000 / 3920 images
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-75496b209c88> in <module>()
#       6 from learn import *
#       7 learn(read_train_traffic_signs(train_path, sample_ratio=.1), read_test_traffic_signs(test_path, sample_ratio=.1),
# ----> 8       [lambda img: img.flatten()[:1000]], model=linear_model.LogisticRegression() )
#
# C:\Users\admin\learn.pyc in learn(train_data, test_data, features, model)
#       7     test_feats = extract_features(test_data[0], features, verbose=True)
#       8     test_labels = test_data[1]
# ----> 9     model.fit(train_feats, train_labels)
# ...

# %% [markdown]
# ##kNN

# %%
# Initiate the kNN, classify, measure accuracy.
#import cv2
from  sklearn import neighbors
import numpy as np
knn = neighbors.KNeighborsClassifier()
#knn.fit(np.array(trainImages), np.array(trainLabels))
print('KNN score: %f' % knn.fit((sample_train_features), (sample_train_labels))
      .score((sample_test_features), sample_test_labels))#, test_labels))
#ret, result, neighbours, dist = knn.find_nearest(np.asarray(test_images), k=5)
# Out:
# KNN score: 0.050000

# %% [markdown]
# ##Logistic Regression

# %%
from sklearn import linear_model
clf = linear_model.LogisticRegression()
print clf.fit(sample_train_features, sample_train_labels).score(sample_test_features, sample_test_labels)
# clf.
# Out:
# 0.13

# %% [markdown]
# ##SVM

# %%
from sklearn import svm
clf = svm.SVC()
print clf.fit(sample_train_features, sample_train_labels).score(sample_test_features, sample_test_labels)
# Out:
# 0.09

# %%
from sklearn import svm
X = [[0, 0], [1, 1]]
y = [0, 1]
clf = svm.SVC()
clf.fit(X, y)  

clf.predict([[2., 2.]])

# get support vectors
print clf.support_vectors_


# get indices of support vectors
print clf.support_ 

# get number of support vectors for each class
print clf.n_support_ 


X = [[0], [1], [2], [3]]
Y = [0, 1, 2, 3]
clf = svm.SVC()#decision_function_shape='ovo')
print clf.fit(X, Y) 




dec = clf.decision_function([[1]])
print dec.shape[1] # 4 classes: 4*3/2 = 6

clf.decision_function_shape = "ovr"
dec = clf.decision_function([[1]])
print dec.shape[1] # 4 classes

lin_clf = svm.LinearSVC()
lin_clf.fit(X, Y) 




dec = lin_clf.decision_function([[1]])
dec.shape[1]
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0, degree=3, gamma=0.0,
#   kernel='rbf', max_iter=-1, probability=False, random_state=None,
#   shrinking=True, tol=0.001, verbose=False)

# %%
# Initiate kNN, train the data, then test it with test data for k=1
import cv2
import numpy as np

knn = cv2.KNearest()
knn.train(np.asarray(train_images),np.asarray(train_labels))
ret,result,neighbours,dist = knn.find_nearest(np.asarray(test_images),k=5)

# Now we check the accuracy of classification
# For that, compare the result with test_labels and check which are wrong
matches = result==np.asarray(test_labels)
correct = np.count_nonzero(matches)
accuracy = correct*100.0/result.size
print accuracy
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-021e62b8282c> in <module>()
#       4
#       5 knn = cv2.KNearest()
# ----> 6 knn.train(np.asarray(train_images),np.asarray(train_labels))
#       7 ret,result,neighbours,dist = knn.find_nearest(np.asarray(test_images),k=5)
#       8
#
# TypeError: responses data type = 18 is not supported

# %%
a = np.array([1, 2])
print a.tolist()

a = np.array([[1, 2], [3, 4]])
print list(a)

print a.tolist()
# Out:
# [1, 2]
# [array([1, 2]), array([3, 4])]
# [[1, 2], [3, 4]]

# %%
import readTrafficSigns#.readTrafficSigns
trainImages, trainLabels = readTrafficSigns.readTrafficSigns(
    'E:\COGNITIVE_SCIENCE\ARTIFICIAL_INTELLIGENCE\ROBOTICS\german_traffic_recog_benchmark\Final_Training\Images')
#import readTrafficSigns
import matplotlib.pyplot as plt
print len(trainLabels), len(trainImages)
plt.imshow(trainImages[400])
plt.show() 
print (trainLabels[400])
x = trainImages[400]#.shape
print x.shape
import numpy as np
#np.reshape(x,(1,))# 30*29*3)
x.flatten().shape
import matplotlib.pyplot as plt
plt.imshow(trainImages[400])#.shape#[1]
plt.show()
import matplotlib.pyplot as plt
import sklearn
# Out:
# 0 0
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-9-38ec10d77b3c> in <module>()
#       5 import matplotlib.pyplot as plt
#       6 print len(trainLabels), len(trainImages)
# ----> 7 plt.imshow(trainImages[400])
#       8 plt.show()
#       9 print (trainLabels[400])
#
# IndexError: list index out of range
